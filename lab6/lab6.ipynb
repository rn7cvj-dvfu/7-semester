# %% [markdown]
# # Задание
#
# Дан датасет с несправедливо осужденными заключенными. Требуется произвести его кластеризацию.
# Для этого требуется:
# 1. Проанализировать данные, выбрать нужные, удалить ненужные столбцы. При необходимости использовать label encoding или one hot encoding для преобразования категориальных признаков в численные.
# 2. Выбрать оптимальное количество кластеров для метода K-means++ при помощи метода локтя.
# 3. Использовать метод K-means++ для кластеризации датасета на оптимальном количестве кластеров, найденном на предыдущем шаге.
# 4. Проанализировать полученные кластеры и интерпретировать результаты.
#
# Ссылка на библиотеку sklearn с реализацией K-means++:
# [ссылка](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %% [markdown]
# ## Установка библиотек и имопрты

# %%
# %pip install pandas numpy plotly nbformat scikit-learn xgboost

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import abc as abc
import sklearn as skl

# %% [markdown]
# ## Загрузка дата сета

# %%
df = pd.read_csv('Wrongful Convictions in the United States.csv')


df_clean = df.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  178 non-null    int64
#  1   Date of the Crime           178 non-null    int64
#  2   Defendants                  178 non-null    object
#  3   Type of the Crime           178 non-null    object
#  4   Location of the Crime       178 non-null    object
#  5   Punishment for a crime      169 non-null    object
#  6   Legally Exonerated          178 non-null    object
#  7   Legally Exonerated Encoded  178 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 11.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  Date of the Crime  Legally Exonerated Encoded
# count  178.000000         178.000000                  178.000000
# mean    88.500000        1980.415730                    0.859551
# std     51.528309          34.544758                    0.348433
# min      0.000000        1805.000000                    0.000000
# 25%     44.250000        1978.000000                    1.000000
# 50%     88.500000        1986.500000                    1.000000
# 75%    132.750000        1998.000000                    1.000000
# max    177.000000        2017.000000                    1.000000

# %%
df.head()
# Out:
#    Unnamed: 0  Date of the Crime                        Defendants  \
# 0           0               1805  Dominic Daley and James Halligan
# 1           1               1843                       John Gordon
# 2           2               1855                      Chief Leschi
# 3           3               1863                 Chipita Rodriguez
# 4           4               1872            William Jackson Marion
#
#   Type of the Crime Location of the Crime Punishment for a crime  \
# 0            murder         Massachusetts                  death
# 1            murder          Rhode Island                  death
# 2            murder            Washington                  death
# 3            murder                 Texas                  death
# 4            murder              Nebraska                  death
#
#   Legally Exonerated  Legally Exonerated Encoded
# 0                yes                           1
# 1                yes                           1
# 2                 no                           0
# 3                yes                           1
# 4                yes                           1

# %% [markdown]
# ## Анализ и подготовка данных

# %%
print("Пропущенные значения:")
print(df_clean.isnull().sum())
print("\nТипы данных:")
print(df_clean.dtypes)
# Out:
# Пропущенные значения:
# Unnamed: 0                    0
# Date of the Crime             0
# Defendants                    0
# Type of the Crime             0
# Location of the Crime         0
# Punishment for a crime        9
# Legally Exonerated            0
# Legally Exonerated Encoded    0
# dtype: int64
#
# Типы данных:
# Unnamed: 0                     int64
# Date of the Crime              int64
# Defendants                    object
# Type of the Crime             object
# Location of the Crime         object
# Punishment for a crime        object
# Legally Exonerated            object
# Legally Exonerated Encoded     int64
# dtype: object

# %%
df_clean = df_clean.drop('Unnamed: 0', axis=1)
df_clean = df_clean.drop('Legally Exonerated Encoded', axis=1)

df_clean = df_clean.dropna()

print(f"Размер датасета после очистки: {df_clean.shape}")
# Out:
# Размер датасета после очистки: (169, 6)

# %%
# Кодируем категориальные переменные
from sklearn.preprocessing import LabelEncoder

le_crime = LabelEncoder()
le_location = LabelEncoder()
le_punishment = LabelEncoder()
le_exonerated = LabelEncoder()
le_defendants = LabelEncoder()

df_clean['Type of the Crime'] = le_crime.fit_transform(df_clean['Type of the Crime'])
df_clean['Location of the Crime'] = le_location.fit_transform(df_clean['Location of the Crime'])
df_clean['Punishment for a crime'] = le_punishment.fit_transform(df_clean['Punishment for a crime'])
df_clean['Legally Exonerated'] = le_exonerated.fit_transform(df_clean['Legally Exonerated'])
df_clean['Defendants'] = le_defendants.fit_transform(df_clean['Defendants'])

print(df_clean.head())
print("\nИтоговые типы данных:")
print(df_clean.dtypes)
# Out:
#    Date of the Crime  Defendants  Type of the Crime  Location of the Crime  \
# 0               1805          43                 16                     16
# 1               1843          74                 16                     30
# 2               1855          21                 16                     35
# 3               1863          22                 16                     33
# 4               1872         166                 16                     21
#
#    Punishment for a crime  Legally Exonerated
# 0                      35                   1
# 1                      35                   1
# 2                      35                   0
# 3                      35                   1
# 4                      35                   1
#
# Итоговые типы данных:
# Date of the Crime         int64
# Defendants                int64
# Type of the Crime         int64
# Location of the Crime     int64
# Punishment for a crime    int64
# Legally Exonerated        int64
# dtype: object

# %%
# Нормализуем данные
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(df_clean)

print(f"Размер матрицы признаков: {X.shape}")
# Out:
# Размер матрицы признаков: (169, 6)

# %% [markdown]
# ## Метод локтя для поиска оптимального k

# %%
from sklearn.cluster import KMeans

inertias = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)


fig = go.Figure()
fig.add_trace(go.Scatter(x=list(k_range), y=inertias, mode='lines+markers', name='Inertia'))
fig.update_layout(title='Метод локтя', xaxis_title='Количество кластеров (k)', yaxis_title='Inertia')
fig.show()

# %%
optimal_k = 5

kmeans = KMeans(n_clusters=optimal_k, init='k-means++', random_state=42)
clusters = kmeans.fit_predict(X)

print(f"Оптимальное количество кластеров: {optimal_k}")
print(f"Распределение по кластерам: {np.bincount(clusters)}")
# Out:
# Оптимальное количество кластеров: 5
# Распределение по кластерам: [53 32 14 46 24]

# %% [markdown]
# ## Анализ кластеров

# %%
df_clean['Cluster'] = clusters

print("Средние значения признаков по кластерам:")
cluster_analysis = df_clean.groupby('Cluster').mean()
print(cluster_analysis)
# Out:
# Средние значения признаков по кластерам:
#          Date of the Crime  Defendants  Type of the Crime  \
# Cluster
# 0              1984.905660   81.735849          16.679245
# 1              1998.812500   98.218750          25.343750
# 2              1884.785714   80.571429          17.142857
# 3              1991.630435   79.021739          16.000000
# 4              1984.583333   81.583333          18.583333
#
#          Location of the Crime  Punishment for a crime  Legally Exonerated
# Cluster
# 0                    10.000000               33.584906            1.000000
# 1                    17.031250               11.031250            1.000000
# 2                    17.357143               33.000000            0.928571
# 3                    29.195652               32.717391            1.000000
# 4                    19.375000               31.333333            0.000000

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

fig = px.scatter(x=X_pca[:, 0], y=X_pca[:, 1], color=clusters, 
                 title='Кластеры (PCA визуализация)',
                 labels={'x': f'PC1 ({pca.explained_variance_ratio_[0]:.2%})',
                        'y': f'PC2 ({pca.explained_variance_ratio_[1]:.2%})'})
fig.show()

# %%
print("Анализ кластеров:\n")

for cluster_id in range(optimal_k):
    cluster_data = df_clean[df_clean['Cluster'] == cluster_id]
    print(f"Кластер {cluster_id}:")
    print(f"  Размер: {len(cluster_data)} образцов")
    print(f"  Средний год: {cluster_data['Date of the Crime'].mean():.0f}")
    print(f"  Всего реабилитирован (без ошибок): {(cluster_data['Legally Exonerated'] == 1).sum()}")
    print()
# Out:
# Анализ кластеров:
#
# Кластер 0:
#   Размер: 53 образцов
#   Средний год: 1985
#   Всего реабилитирован (без ошибок): 53
#
# Кластер 1:
#   Размер: 32 образцов
#   Средний год: 1999
#   Всего реабилитирован (без ошибок): 32
#
# Кластер 2:
#   Размер: 14 образцов
#   Средний год: 1885
#   Всего реабилитирован (без ошибок): 13
#
# Кластер 3:
#   Размер: 46 образцов
#   Средний год: 1992
#   Всего реабилитирован (без ошибок): 46
#
# Кластер 4:
#   Размер: 24 образцов
#   Средний год: 1985
#   Всего реабилитирован (без ошибок): 0
